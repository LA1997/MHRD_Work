# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('KeywordinCitationsReduced.xlsx')

# %%
df
# Out:
#                                 Keyword  \
# 0           Navigation Facility for VIP
# 1        Communication Facility for VIP
# 2   Touch Based Functionalities for VIP
# 3            Healthcare Systems for VIP
# 4  Multilingual Reading Systems for VIP
# 5                     Education for VIP
# 6        Systems for Independent Living
# 7                         crowdsourcing
# 8                                Others
#
#                                                Count  1990s  2002  2003  2004  \
# 0  ['0', '2', '131', '132', '5', '6', '7', '9', '...      0     1     0     0
# 1  ['36', '37', '102', '43', '12', '111', '49', '...      0     0     0     0
# 2  ['6', '8', '9', '22', '34', '35', '48', '55', ...      0     0     0     0
# 3    ['0', '67', '7', '42', '74', '44', '112', '93']      0     0     0     0
# 4  ['99', '3', '36', '102', '7', '13', '85', '55'...      0     0     0     0
# 5   ['34', '99', '36', '5', '38', '110', '23', '88']      0     0     0     0
# ...

# %%
def stringtolist(li):
    return [x.strip("'") for x in li.strip('][').split(', ')]

for i in range(len(df)):
    df = df.astype(object)
    df.loc[i,'Count'] = stringtolist(df.loc[i,'Count'])
    df.loc[i,'Total'] = len(df.loc[i,'Count'])
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
# 2019 Division 
labels = list(df['Keyword'])
sizes = list(df['2019'])

colors = []
explode = (100, 0, 100, 0,100,0,100,0,0) # explode 1st slice


fig1, ax1 = plt.subplots(figsize=(6, 5))
fig1.subplots_adjust(0.3,0,1,1)


# Plot
plt.pie(sizes, explode=explode,autopct='%1.1f%%', shadow=True, startangle=140,radius=1000)

ax1.axis('equal')

total = sum(sizes)
plt.legend(
    loc='upper right',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, sizes)],
    prop={'size': 11},
    bbox_to_anchor=(0.0, 1),
    bbox_transform=fig1.transFigure
)

plt.show()

# %%
# Overall Division 
labels = list(df['Keyword'])
sizes = list(df['Total'])

colors = []
explode = (100, 0, 100, 0,100,0,100,0,0)  # explode 1st slice


fig1, ax1 = plt.subplots(figsize=(6, 5))
fig1.subplots_adjust(0.3,0,1,1)


# Plot
plt.pie(sizes, explode=explode,autopct='%1.1f%%', shadow=True, startangle=140,radius=1000)

ax1.axis('equal')

total = sum(sizes)
plt.legend(
    loc='upper right',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, sizes)],
    prop={'size': 11},
    bbox_to_anchor=(0.0, 1),
    bbox_transform=fig1.transFigure
)

plt.show()

# %%
# YearWise Division 
fig1, ax1 = plt.subplots(figsize=(15, 5))
fig1.subplots_adjust(0.3,0,1,1)

labels = list(df.columns[2:-1])
sizes = [sum(df.loc[0:,x]) for x in labels]

# plt.yticks(range(1,25))

plt.plot(labels,sizes,marker='o')

# %%
df.loc[0,'Keyword'] = 'Navigation Facility for VIP'
df.loc[1,'Keyword'] = 'Communication Facility for VIP'
df.loc[2,'Keyword'] = 'Touch Based Functionalities for VIP'
df.loc[3,'Keyword'] = 'Healthcare Systems for VIP'
df.loc[4,'Keyword'] = 'Multilingual Reading Systems for VIP'          #Text-to-Speech

# %%
df.iloc[6,1] = df.iloc[6,1] + df.iloc[8,1] + df.iloc[10,1] + df.iloc[12,1] + df.iloc[13,1]
df.iloc[6,2:] = df.iloc[6,2:] + df.iloc[8,2:] + df.iloc[10,2:]+ df.iloc[12,2:] + df.iloc[13,2:]

# %%
df.loc[5,'Keyword'] = 'Education for VIP'
df.loc[6,'Keyword'] = 'Systems for Independent Living'  #Objects Detection, semi-autonomous vehicles, color sensors, Easy shopping etc.
df = df.astype(object)
df.loc[6,'Count'] = [4,62,114,132,12,112,86,55,121,6]

# %%
# df.drop(index=[7,8,10,12,13,16],inplace=True)

# df.drop(index=[8,10,11],inplace=True)

df.drop(index=[9],inplace=True)

# %%
df.iloc[7,1] = df.iloc[7,1] + df.iloc[11,1] + df.iloc[8,1] + df.iloc[10,1]
df.iloc[7,2:] = df.iloc[7,2:] + df.iloc[11,2:] + df.iloc[8,2:]+ df.iloc[10,2:]

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#                                 Keyword  \
# 0           Navigation Facility for VIP
# 1        Communication Facility for VIP
# 2   Touch Based Functionalities for VIP
# 3            Healthcare Systems for VIP
# 4  Multilingual Reading Systems for VIP
# 5                     Education for VIP
# 6        Systems for Independent Living
# 7                                Others
# 8                         crowdsourcing
#
#                                                Count 1990s 2002 2003 2004  \
# 0  [0, 2, 131, 132, 5, 6, 7, 9, 10, 11, 140, 14, ...     0    1    0    0
# 1                 [36, 37, 102, 43, 12, 111, 49, 61]     0    0    0    0
# 2  [6, 8, 9, 22, 34, 35, 48, 55, 57, 62, 63, 64, ...     0    0    0    0
# 3                    [0, 67, 7, 42, 74, 44, 112, 93]     0    0    0    0
# 4           [99, 3, 36, 102, 7, 13, 85, 55, 56, 121]     0    0    0    0
# 5                   [34, 99, 36, 5, 38, 110, 23, 88]     0    0    0    0
# ...

# %%
df.loc[7,'Keyword'] = 'Others'            #Ergonomics, Behavioural Sciences, IOT Based, Gaming, etc
df.loc[7,'Count'] = [52,104,9,132,7,83,13]

# %%
df.loc[9] = df.loc[8]
df.loc[8] = df.loc[7]
df.loc[7] = df.loc[9]

# %%
df.to_excel('KeywordinCitationsReduced.xls',index=False)

# %%
# Out:
# str
